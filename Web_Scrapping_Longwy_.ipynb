# %% [markdown]
# <a href="https://colab.research.google.com/github/Sitraka17/Learning-Data-Science/blob/main/Web_Scrapping_Longwy_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Today I will try to find the best flat in the 54000 Region (France) in order to work in this wonderplace called Luxembourg <3 

 # URL: https://www.immoregion.fr/location/appartement/longwy

# %%
from urllib.request import urlopen

html = urlopen('https://www.immoregion.fr/location/appartement/longwy.html')
print(html.read())
# Out:
# b'<!DOCTYPE html><html lang="fr"><head><title data-react-helmet="true">Location Appartement \xc3\xa0  \xe2\x96\xb7 Voir les Annonces | immoRegion</title><meta data-react-helmet="true" charSet="utf-8"/><meta data-react-helmet="true" name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no"/><meta data-react-helmet="true" http-equiv="x-ua-compatible" content="ie=edge"/><meta data-react-helmet="true" name="description" content="\xe2\x9c\x93 Appartement \xc3\xa0 Louer  \xe2\x96\xb7 Voir les Appartement en location \xc3\xa0  : Trouvez votre futur bien sur immoRegion"/><meta data-react-helmet="true" name="robots" content="noindex, follow"/><meta data-react-helmet="true" property="og:description" content="\xe2\x9c\x93 Appartement \xc3\xa0 Louer  \xe2\x96\xb7 Voir les Appartement en location \xc3\xa0  : Trouvez votre futur bien sur immoRegion"/><meta data-react-helmet="true" property="og:image" content="/portal-srp/assets/images/fr/logo.svg"/><meta data-react-helmet="tr
# ...

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

html = urlopen('https://www.immoregion.fr/location/appartement/longwy.html')
bs = BeautifulSoup(html.read(), 'html.parser')
print(bs.h1)
# Out:
# <h1>Location Appartement à </h1>

# %% [markdown]
# Hum...what if
